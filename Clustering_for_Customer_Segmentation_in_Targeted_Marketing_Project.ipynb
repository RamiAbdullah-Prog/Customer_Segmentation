# %% [markdown]
# [link text](https://www.kaggle.com/datasets/zohrenotash/customer-datasets/data)

# %% [markdown]
#     Clustering for Customer Segmentation in Targeted Marketing

# %% [markdown]
# ---
#
# ### **Project Proposal: Customer Segmentation for Targeted Marketing in the Banking Sector Using Machine Learning**
#
# ---
#
# #### **1. Project Introduction:**
# The primary objective of this project is to apply unsupervised learning techniques, specifically the **K-Means clustering algorithm**, to segment customers based on their credit card usage behaviors. This segmentation will enable the bank’s marketing team to develop more personalized and effective marketing strategies. By identifying groups of customers with similar behaviors, the bank can tailor offers, promotions, and discounts to these segments.
# Using **K-Means** combined with **Principal Component Analysis (PCA)** for dimensionality reduction, the project aims to cluster customers based on their spending habits, credit usage, and payment patterns. This approach will help the bank optimize marketing efforts, reduce resource wastage, and increase the effectiveness of promotional campaigns.
#
# ---
#
# #### **2. Project Objectives:**
# The main objectives of this project are:
# - **Customer Segmentation:** Segmenting customers based on their credit card usage behaviors such as balance, transactions, payments, credit limit, etc.
# - **Clustering Using K-Means:** Applying **K-Means clustering** to group customers with similar behaviors.
# - **Dimensionality Reduction with PCA:** Using **Principal Component Analysis (PCA)** to reduce the dimensionality of the data and enhance cluster visualization.
# - **Marketing Insights:** Providing actionable insights to the bank’s marketing team on how to more effectively target different customer groups.
#
# ---
#
# #### **3. Available Dataset:**
# The dataset consists of information about **8950 active credit card holders** with 18 variables related to their credit card usage over a certain period.
# **Key features** in the dataset include:
#
# - **CUST_ID:** Unique identifier for each customer (text field).
# - **BALANCE:** Current balance on the credit card.
# - **BALANCE_FREQUENCY:** Frequency of balance updates.
# - **PURCHASES:** Total amount spent by the customer during the given period.
# - **ONEOFF_PURCHASES:** Amount spent on one-time purchases.
# - **INSTALLMENTS_PURCHASES:** Amount spent on installment purchases.
# - **CASH_ADVANCE:** Amount of cash withdrawn from the credit card.
# - **PURCHASES_FREQUENCY:** Frequency of purchases made by the customer.
# - **ONEOFF_PURCHASES_FREQUENCY:** Frequency of one-off purchases.
# - **PURCHASES_INSTALLMENTS_FREQUENCY:** Frequency of installment purchases.
# - **CASH_ADVANCE_FREQUENCY:** Frequency of cash advances.
# - **CASH_ADVANCE_TRX:** Number of cash advance transactions.
# - **PURCHASES_TRX:** Number of purchase transactions.
# - **CREDIT_LIMIT:** Total credit limit of the customer.
# - **PAYMENTS:** Total payments made by the customer.
# - **MINIMUM_PAYMENTS:** Minimum payments (some missing values).
# - **PRC_FULL_PAYMENT:** Percentage of full payments made.
# - **TENURE:** Number of months the customer has had the credit card.
#
# **Notes:**
# - There are some missing values in the **CREDIT_LIMIT** and **MINIMUM_PAYMENTS** columns, which will be handled during the preprocessing stage.
#
# ---
#
# #### **4. Methodology:**
#
# **Stage 1: Data Exploration (EDA):**
# - **Visualization:** Use histograms, box plots, and correlation matrices to understand the distribution and relationships between features.
# - **Handling Missing Data:** Handle missing values in **CREDIT_LIMIT** and **MINIMUM_PAYMENTS** using imputation techniques or deletion.
# - **Outlier Detection:** Use box plots and scatter plots to detect outliers in key features like **balance**, **purchases**, and **payments**, and treat them appropriately.
#
# **Stage 2: Data Preprocessing:**
# - **Handling Missing Values:** Missing values in **CREDIT_LIMIT** and **MINIMUM_PAYMENTS** will be handled using mean imputation or deletion based on the analysis.
# - **Data Scaling:** Since **K-Means** is sensitive to the scale of the data, we will **standardize** the data using **StandardScaler**.
# - **Feature Removal:** The **CUST_ID** column will be removed as it is not relevant for clustering.
#
# **Stage 3: Clustering Using K-Means:**
# - **Choosing the Optimal Number of Clusters (K):** We will use the **Elbow Method** and **Silhouette Score** to determine the optimal number of clusters.
#   - **Elbow Method:** This method involves plotting the within-cluster sum of squares (WCSS) for different values of K and identifying the "elbow" point where the improvement starts to slow.
#   - **Silhouette Score:** Measures how similar an object is to its own cluster compared to other clusters. A higher score indicates better clustering.
# - **Applying K-Means Clustering:** After determining the optimal K, we will apply the **K-Means** algorithm to segment the customers.
#
# **Stage 4: Dimensionality Reduction Using PCA:**
# - **PCA:** **Principal Component Analysis (PCA)** will be used to reduce the dimensionality of the data to 2 or 3 dimensions for easier visualization and interpretation of the clusters.
# - **Visualization:** We will visualize the clusters in a 2D space using the first two principal components.
#
# **Stage 5: Post-Clustering Analysis:**
# - **Cluster Profiling:** After clustering, we will analyze the centroids of each cluster to understand the main characteristics of customers in each group.
#   - Example: Cluster 1 may have customers with high credit usage but low payments, Cluster 2 may have low credit usage with frequent payments, and so on.
# - **Actionable Insights:** Based on the characteristics of each cluster, we will provide recommendations to the marketing team on how to tailor promotional strategies for each group.
#
# ---
#
# #### **5. Proposed Models and Techniques:**
#
# - **K-Means Clustering:** This unsupervised learning algorithm will be used to identify clusters of customers based on their behavior.
# - **Principal Component Analysis (PCA):** To reduce dimensionality and visualize clusters in a 2D or 3D space.
# - **Elbow Method and Silhouette Score:** These techniques will help determine the optimal number of clusters for K-Means.
#
# ---
#
# #### **6. Tools and Technologies Used:**
#
# - **Programming Language:** Python
# - **Libraries:**
#   - **Pandas:** For data manipulation.
#   - **NumPy:** For numerical operations.
#   - **Seaborn** and **Matplotlib:** For visualization.
#   - **Scikit-learn:** For machine learning models (K-Means, PCA, StandardScaler).
# - **Techniques:** **Unsupervised Learning**, **Clustering**, **Dimensionality Reduction (PCA)**.
#
# ---
#
# #### **7. Expected Outcomes:**
# - **Customer Segmentation:** Customers will be grouped into clusters with similar behaviors, providing the bank with a deeper understanding of their customer base.
# - **Actionable Marketing Insights:** Based on the clusters, we will provide the marketing team with recommendations on how to target each group more effectively.
# - **Visualizations:** Clear visualizations (e.g., PCA plots, cluster profiles) will help the team in decision-making.
#
# ---
#
# #### **8. Potential Challenges:**
# - **Determining the Optimal Number of Clusters (K):** Selecting the right number of clusters using methods like the **Elbow Method** and **Silhouette Score** may be challenging and require careful evaluation.
# - **Handling Missing Data:** Ensuring proper handling of missing values without losing important information can be tricky.
# - **Interpreting Clusters:** Interpreting the characteristics of each cluster might be challenging, especially without domain knowledge.
#
# ---
#
# #### **9. Conclusion:**
# This project will leverage **unsupervised learning techniques**, particularly **K-Means clustering**, to segment customers based on their credit card usage behavior. By identifying clusters with similar characteristics, the bank will be able to allocate its marketing resources more efficiently and develop more effective promotional strategies, ultimately improving the success of marketing campaigns and increasing profitability.
#
# ---

# %% [markdown]
# ##  **Importing Essential Libraries**
#
# - In this step, we import the essential libraries we need to work with:
#   - `numpy`: A library for mathematical operations and numerical analysis.
#   - `pandas`: A library for data manipulation, such as reading data from files, cleaning, and analysis.
#   - `seaborn`: A library for advanced plotting and data visualization.
#   - `matplotlib`: A library for creating basic plots.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ---
#
# ## **Reading the Data**
#
# - In this step, we read CSV data files:
#   - `df_train`: The training data.
# - Then, we display the first $5$ rows of each dataset using `.head(5)` to review the content.

# %%
data = pd.read_csv('/content/drive/MyDrive/Data File/09_Customer_segmentation_Data /01_Customer_Segmentation_Data.csv')

# %%
data.head(5)
# Out:
#   CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0  C10001    40.900749           0.818182      95.40              0.00
# 1  C10002  3202.467416           0.909091       0.00              0.00
# 2  C10003  2495.148862           1.000000     773.17            773.17
# 3  C10004  1666.670542           0.636364    1499.00           1499.00
# 4  C10005   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# ...

# %% [markdown]
# ---
#
# ## **Exploring the Data**
#
# - We use several methods to explore the data:
#   - `.info()`: To get information about the columns, data types, and non-null values.
#   - `.describe().T`: To get basic statistics like mean, standard deviation, and transpose the results for clarity.
#   - `.columns`: To list the column names.
#   - `.shape`: To get the dimensions of the dataset (number of rows and columns).

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8950 entries, 0 to 8949
# Data columns (total 18 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   CUST_ID                           8950 non-null   object
#  1   BALANCE                           8950 non-null   float64
#  2   BALANCE_FREQUENCY                 8950 non-null   float64
#  3   PURCHASES                         8950 non-null   float64
#  4   ONEOFF_PURCHASES                  8950 non-null   float64
#  5   INSTALLMENTS_PURCHASES            8950 non-null   float64
#  6   CASH_ADVANCE                      8950 non-null   float64
#  7   PURCHASES_FREQUENCY               8950 non-null   float64
#  8   ONEOFF_PURCHASES_FREQUENCY        8950 non-null   float64
#  9   PURCHASES_INSTALLMENTS_FREQUENCY  8950 non-null   float64
#  10  CASH_ADVANCE_FREQUENCY            8950 non-null   float64
# ...

# %%
data.describe().T
# Out:
#                                    count         mean          std        min  \
# BALANCE                           8950.0  1564.474828  2081.531879   0.000000
# BALANCE_FREQUENCY                 8950.0     0.877271     0.236904   0.000000
# PURCHASES                         8950.0  1003.204834  2136.634782   0.000000
# ONEOFF_PURCHASES                  8950.0   592.437371  1659.887917   0.000000
# INSTALLMENTS_PURCHASES            8950.0   411.067645   904.338115   0.000000
# CASH_ADVANCE                      8950.0   978.871112  2097.163877   0.000000
# PURCHASES_FREQUENCY               8950.0     0.490351     0.401371   0.000000
# ONEOFF_PURCHASES_FREQUENCY        8950.0     0.202458     0.298336   0.000000
# PURCHASES_INSTALLMENTS_FREQUENCY  8950.0     0.364437     0.397448   0.000000
# CASH_ADVANCE_FREQUENCY            8950.0     0.135144     0.200121   0.000000
# CASH_ADVANCE_TRX                  8950.0     3.248827     6.824647   0.000000
# ...

# %%
data.columns
# Out:
# Index(['CUST_ID', 'BALANCE', 'BALANCE_FREQUENCY', 'PURCHASES',
#        'ONEOFF_PURCHASES', 'INSTALLMENTS_PURCHASES', 'CASH_ADVANCE',
#        'PURCHASES_FREQUENCY', 'ONEOFF_PURCHASES_FREQUENCY',
#        'PURCHASES_INSTALLMENTS_FREQUENCY', 'CASH_ADVANCE_FREQUENCY',
#        'CASH_ADVANCE_TRX', 'PURCHASES_TRX', 'CREDIT_LIMIT', 'PAYMENTS',
#        'MINIMUM_PAYMENTS', 'PRC_FULL_PAYMENT', 'TENURE'],
#       dtype='object')

# %%
data.shape
# Out:
# (8950, 18)

# %% [markdown]
# ---
#
# ### **Data Summary**
#
# The dataset consists of **18 columns** and **8950 rows**. The columns are categorized as follows:
#
# - **Numerical (float64)**:
#   - **BALANCE**, **BALANCE_FREQUENCY**, **PURCHASES**, **ONEOFF_PURCHASES**, **INSTALLMENTS_PURCHASES**, **CASH_ADVANCE**, **PURCHASES_FREQUENCY**, **ONEOFF_PURCHASES_FREQUENCY**, **PURCHASES_INSTALLMENTS_FREQUENCY**, **CASH_ADVANCE_FREQUENCY**, **CREDIT_LIMIT**, **PAYMENTS**, **PRC_FULL_PAYMENT**.
#
# - **Numerical (int64)**:
#   - **CASH_ADVANCE_TRX**, **PURCHASES_TRX**, **TENURE**.
#
# - **Categorical (object)**:
#   - **CUST_ID** (unique identifier for each customer).
#
# ### **Key Insights:**
# - The dataset includes a mix of **financial** and **transactional** features, with most columns containing **float64** values reflecting monetary figures and frequencies.
# - **int64 columns** represent transaction counts and the duration of customer relationships.
# - **CUST_ID** is a categorical column used to uniquely identify customers.
#
# ### **Data Completeness:**
# - Most columns have **no missing values**, except for **CREDIT_LIMIT** (1 missing value) and **MINIMUM_PAYMENTS** (313 missing values).
#
# ---

# %% [markdown]
# ---
#
# ## **Checking for Missing Values**
#
# - We check for missing values in the training and test datasets using `.isnull().sum()` to see how many missing values exist in each column.
# - If there are columns with missing values, we display them using the condition `missing_values > 0`.

# %%
missing_values = data.isnull().sum()
missing_columns = missing_values[missing_values > 0]
missing_columns
# Out:
# CREDIT_LIMIT          1
# MINIMUM_PAYMENTS    313
# dtype: int64

# %% [markdown]
# ---
#
# ### **Handling Missing Values**
#
# In this step, we handle missing values by filling them using the **Median** for the relevant columns.
#
# - **CREDIT_LIMIT**:
#   There is **1 missing value** in this column. We will fill this missing value using the **median** of the available data in this column.
#
# - **MINIMUM_PAYMENTS**:
#   There are **313 missing values** in this column. These will also be filled using the **median**.
#
# No other columns contain missing values, so no further imputation is necessary.
#
# ---

# %%
data['CREDIT_LIMIT'] = data['CREDIT_LIMIT'].fillna(data['CREDIT_LIMIT'].median())
data['MINIMUM_PAYMENTS'] = data['MINIMUM_PAYMENTS'].fillna(data['MINIMUM_PAYMENTS'].median())

# %% [markdown]
# -  The median was chosen instead of the mean to avoid the potential impact of outliers or extreme values.

# %% [markdown]
# ---
#
# ### **Checking for Missing Values After Handling**
#
# - After handling the missing values, we check again to make sure there are no missing values using `.isnull().sum()` to verify that all missing values have been handled.

# %%
data.isnull().sum()
# Out:
# CUST_ID                             0
# BALANCE                             0
# BALANCE_FREQUENCY                   0
# PURCHASES                           0
# ONEOFF_PURCHASES                    0
# INSTALLMENTS_PURCHASES              0
# CASH_ADVANCE                        0
# PURCHASES_FREQUENCY                 0
# ONEOFF_PURCHASES_FREQUENCY          0
# PURCHASES_INSTALLMENTS_FREQUENCY    0
# CASH_ADVANCE_FREQUENCY              0
# CASH_ADVANCE_TRX                    0
# PURCHASES_TRX                       0
# CREDIT_LIMIT                        0
# PAYMENTS                            0
# MINIMUM_PAYMENTS                    0
# PRC_FULL_PAYMENT                    0
# TENURE                              0
# dtype: int64

# %% [markdown]
# ---
#
# ## **Data Visualization 🔎**
#
# Given that all columns in the dataset are numerical, there is no need to classify the data into **numerical** and **categorical** categories.
#
# To maintain the integrity of the original data, we will:
#
# - Create a copy of the dataset, **excluding the CUST_ID column**.
# - Apply various visualizations to this new dataset copy to explore and better understand the data distribution and relationships between features.
#
# ---

# %%
df = data.copy()

# %%
df = df.drop(columns='CUST_ID')

# %% [markdown]
# ---
#
# ### 🔻 $^ Correlation Matrix & Heatmap ^$
#
# - We display a correlation matrix between the columns using `corr()` to understand the relationships between variables.
# - This is visualized using a `heatmap` to show the strength of the relationships.

# %%
Correlation_Matrix = df.corr()
Correlation_Matrix.T
# Out:
#                                    BALANCE  BALANCE_FREQUENCY  PURCHASES  \
# BALANCE                           1.000000           0.322412   0.181261
# BALANCE_FREQUENCY                 0.322412           1.000000   0.133674
# PURCHASES                         0.181261           0.133674   1.000000
# ONEOFF_PURCHASES                  0.164350           0.104323   0.916845
# INSTALLMENTS_PURCHASES            0.126469           0.124292   0.679896
# CASH_ADVANCE                      0.496692           0.099388  -0.051474
# PURCHASES_FREQUENCY              -0.077944           0.229715   0.393017
# ONEOFF_PURCHASES_FREQUENCY        0.073166           0.202415   0.498430
# PURCHASES_INSTALLMENTS_FREQUENCY -0.063186           0.176079   0.315567
# CASH_ADVANCE_FREQUENCY            0.449218           0.191873  -0.120143
# CASH_ADVANCE_TRX                  0.385152           0.141555  -0.067175
# PURCHASES_TRX                     0.154338           0.189626   0.689561
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(16,8))
sns.heatmap(Correlation_Matrix,
            annot=True,
            linecolor='white',
            linewidths=0.7,
            cmap='cividis')

plt.title('Heat map for numerical columns')
plt.show()

# %% [markdown]
# ---
#
# ### **Correlation Matrix Documentation**
#
# The correlation matrix illustrates the relationships between different variables in the dataset.
#
# #### **Key Insights:**
#
# 1. **Strong Positive Correlations:**
#    - **PURCHASES and ONEOFF_PURCHASES**
#      A strong positive correlation of **(≈ 0.92)** indicates that purchases are heavily dependent on one-off purchases.
#
#    - **PURCHASES_FREQUENCY and PURCHASES_INSTALLMENTS_FREQUENCY**
#      A strong correlation of **(≈ 0.86)** suggests that customers who make frequent purchases tend to use installment plans more often.
#
#    - **CASH_ADVANCE_FREQUENCY and CASH_ADVANCE_TRX**
#      A strong correlation of **(≈ 0.8)** indicates that the frequency of cash advances is aligned with the number of cash advance transactions.
#
# 2. **Moderate Positive Correlations:**
#    - **BALANCE and CREDIT_LIMIT**
#      A moderate correlation of **(≈ 0.53)** implies that the credit limit partially influences the balance.
#
#    - **PURCHASES and PURCHASES_TRX**
#      A moderate correlation of **(≈ 0.69)** suggests that the total amount of purchases is related to the number of transactions.
#
#    - **CASH_ADVANCE and CASH_ADVANCE_TRX**
#      A moderate correlation of **(≈ 0.66)** indicates that the amount of cash advances is related to the number of cash advance transactions.
#
# 3. **Weak Correlations:**
#    - **TENURE and other columns**
#      Most correlations with **TENURE** are very weak, suggesting that the length of the customer's relationship with the bank does not significantly correlate with other features.
#
#    - **PRC_FULL_PAYMENT with other columns**
#      A weak correlation with most columns suggests that the full payment percentage is not significantly related to other variables.
#
# 4. **Negative Correlations:**
#    - **PRC_FULL_PAYMENT and BALANCE**
#      A weak negative correlation of **(≈ -0.32)** suggests that as the percentage of full payments increases, the balance tends to decrease.
#
#    - **PRC_FULL_PAYMENT and CASH_ADVANCE_FREQUENCY**
#      A weak negative correlation of **(≈ -0.25)** indicates that customers who frequently take cash advances tend to pay a lower percentage of their full balance.

# %% [markdown]
# ---
#
# ### 🔻 $^ Scatterplot for Numeric Columns ^$
#
#
# - We present a `scatterplot` to show the relationship between `PURCHASES` and `ONEOFF_PURCHASES`
#
# - We present a `barplot` to show the total purchases by type, comparing `PURCHASES`, `ONEOFF_PURCHASES`, and `INSTALLMENTS_PURCHASES` across the dataset.
#
# - We present a `scatterplot` to show the relationship between `PURCHASES_FREQUENCY` and `PURCHASES_INSTALLMENTS_FREQUENCY`
#
# - We present a `scatterplot` to show the relationship between `CASH_ADVANCE` and `CASH_ADVANCE_FREQUENCY`
#
# - We present a `scatterplot` to show the relationship between `CREDIT_LIMIT` and `BALANCE`
#
# - We present a `scatterplot` to show the relationship between `MINIMUM_PAYMENTS` and `PAYMENTS`
#
# - We present a `scatterplot` to show the relationship between `PRC_FULL_PAYMENT` and `BALANCE`
#
# - We present a `scatterplot` to show the relationship between `PURCHASES` and `BALANCE`
#
# - We present a `scatterplot` to show the relationship between `PURCHASES_FREQUENCY` and `CASH_ADVANCE`
#
# ---

# %% [markdown]
# - relationship between `PURCHASES` and `ONEOFF_PURCHASES`

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(14,7))

sns.scatterplot(data=df,
                x='PURCHASES',
                y='ONEOFF_PURCHASES',
                hue='PURCHASES',
                palette='viridis',
                alpha=0.7,
                size='ONEOFF_PURCHASES',
                sizes=(20, 200))

plt.title('Purchases vs One-off Purchases')
plt.xlabel('Purchases')
plt.ylabel('One-off Purchases')
plt.show()

# %% [markdown]
# ---
# #### **Purchases vs One-off Purchases**
# **Description:**
# The chart shows the relationship between total purchases and one-off purchases made by customers.
#
# **Key Observations:**
# - There is a positive correlation between total purchases and one-off purchases.
# - Customers who make more purchases are also more likely to make one-off purchases.
#
# **Conclusion:**
# Customers who make a high number of one-off purchases can be targeted with special promotions.
#
#
# ---

# %% [markdown]
# - relationship between `PURCHASES`, `ONEOFF_PURCHASES`, and `INSTALLMENTS_PURCHASES`

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(14,7))
Colors = ['#610f7f', '#62b6cb', '#a7c957']

ColumnName = ['PURCHASES', 'ONEOFF_PURCHASES', 'INSTALLMENTS_PURCHASES']
Total = [df['PURCHASES'].sum(), df['ONEOFF_PURCHASES'].sum(), df['INSTALLMENTS_PURCHASES'].sum()]

sns.barplot(x=ColumnName , y=Total , hue=ColumnName , palette=Colors)

plt.title('Total Purchases by Type', fontsize=16)
plt.ylabel('Total Purchases', fontsize=14)
plt.xlabel('Purchase Types', fontsize=14)
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# - relationship between `PURCHASES_FREQUENCY` and `PURCHASES_INSTALLMENTS_FREQUENCY`

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(14, 7))

sns.scatterplot(data=df,
                x='PURCHASES_FREQUENCY',
                y='PURCHASES_INSTALLMENTS_FREQUENCY',
                hue='PURCHASES_FREQUENCY',
                palette='viridis',
                alpha=0.7,
                size='PURCHASES_INSTALLMENTS_FREQUENCY',
                sizes=(20, 200))

plt.title('Purchases Frequency vs Purchases Installments Frequency')
plt.xlabel('Purchases Frequency')
plt.ylabel('Purchases Installments Frequency')
plt.legend(title='Frequency', loc='upper left')
plt.show()

# %% [markdown]
# ---
#
# #### **Purchases vs Installment Purchases**
# **Description:**
# The scatter plot shows the relationship between the frequency of purchases and the frequency of installment purchases.
#
# **Key Observations:**
# - There is a positive correlation between the frequency of purchases and installment purchases.
# - Customers with higher purchase frequencies are more likely to use installments.
#
# **Conclusion:**
# Frequent buyers are more inclined to use installment plans, possibly due to larger purchase amounts or financial management preferences.
#
# ---

# %% [markdown]
# - relationship between `CASH_ADVANCE` and `CASH_ADVANCE_FREQUENCY`

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(14,7))

sns.scatterplot(data=df,
                x='CASH_ADVANCE',
                y='CASH_ADVANCE_FREQUENCY',
                hue='CASH_ADVANCE',
                palette='viridis',
                alpha=0.7,
                size='CASH_ADVANCE_FREQUENCY',
                sizes=(20, 200))

plt.title('Cash Advance vs Cash Advance Frequency')
plt.xlabel('Cash Advance')
plt.ylabel('Cash Advance Frequency')
plt.show()

# %% [markdown]
# ---
#
# #### **Cash Advance vs Cash Advance Frequency**
# **Description:**
# The scatter plot shows the relationship between the amount of cash advance and the frequency of cash advances.
#
# **Key Observations:**
# - There is a general positive relationship between cash advance amounts and the frequency of cash advances.
# - Customers who take larger cash advances tend to take cash advances more frequently.
#
# **Conclusion:**
# The data suggests that higher cash advance amounts are associated with more frequent cash advances, indicating that those who need larger amounts are likely to make regular withdrawals.
#
# ---

# %% [markdown]
# - relationship between `CREDIT_LIMIT` and `BALANCE`

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(14,7))

sns.scatterplot(data=df,
                x='CREDIT_LIMIT',
                y='BALANCE',
                hue='CREDIT_LIMIT',
                palette='viridis',
                alpha=0.7,
                size='BALANCE',
                sizes=(20, 200))

plt.title('Balance vs Credit Limit')
plt.xlabel('Credit Limit')
plt.ylabel('Balance')
plt.show()

# %% [markdown]
# ---
#
# #### **Balance vs Credit Limit**
# **Description:**
# The scatter plot shows the relationship between a customer's balance and their credit limit.
#
# **Key Observations:**
# - There is a positive correlation between balance and credit limit.
# - Customers with higher credit limits tend to have higher balances.
# - Larger credit limits allow customers to maintain larger balances.
#
# **Conclusion:**
# Higher credit limits are associated with higher customer balances, suggesting that increased credit capacity enables customers to carry larger balances.
#
# ---

# %% [markdown]
# - relationship between `MINIMUM_PAYMENTS` and `PAYMENTS`

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(14,7))

sns.scatterplot(data=df,
                x='MINIMUM_PAYMENTS',
                y='PAYMENTS',
                hue='MINIMUM_PAYMENTS',
                palette='viridis',
                alpha=0.7,
                size='PAYMENTS',
                sizes=(20, 200))

plt.title('Payments vs Minimum Payments')
plt.xlabel('Minimum Payments')
plt.ylabel('Payments')
plt.show()

# %% [markdown]
# ---
#
# #### **Minimum Payments vs Payments**
# **Description:**
# The scatter plot shows the relationship between minimum payments and total payments.
#
# **Key Observations:**
# - Most data points are clustered around lower values of both minimum payments and payments.
# - As minimum payments increase, the number of data points decreases.
# - There is a general positive correlation between minimum payments and total payments, although not consistently.
# - Some outliers have high payment values but low minimum payments.
#
# **Conclusion:**
# Increased minimum payments are generally associated with higher total payments, though there are exceptions, particularly among outliers.
#
# ---

# %% [markdown]
# - relationship between `PRC_FULL_PAYMENT` and `BALANCE`

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(14,7))

sns.scatterplot(data=df,
                x='PRC_FULL_PAYMENT',
                y='BALANCE',
                hue='PRC_FULL_PAYMENT',
                palette='viridis',
                alpha=0.7,
                size='BALANCE',
                sizes=(20, 200))

plt.title('PRC Full Payment vs Balance')
plt.xlabel('PRC Full Payment')
plt.ylabel('Balance')
plt.show()

# %% [markdown]
# ---
#
# #### **PRC Full Payment vs Balance**
# **Description:**
# The scatter plot shows the relationship between "PRC Full Payment" and "Balance."
#
# **Key Observations:**
# - There is a negative correlation between "PRC Full Payment" and "Balance." As the percentage of full payment increases, the balance tends to decrease.
# - Customers with higher full payment percentages generally have lower balances.
# - Most payments are either very small or very large, with fewer moderate payments.
#
# **Conclusion:**
# Higher full payment percentages are associated with lower balances, suggesting that customers who pay more upfront tend to carry smaller balances.
#
# ---

# %% [markdown]
# - relationship between `PURCHASES` and `BALANCE`

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(14,7))

sns.scatterplot(data=df,
                x='BALANCE',
                y='PURCHASES',
                hue='BALANCE',
                palette='viridis',
                alpha=0.7,
                size='PURCHASES',
                sizes=(20, 200))

plt.title('Purchases vs Balance')
plt.xlabel('BALANCE')
plt.ylabel('PURCHASES')
plt.show()

# %% [markdown]
# ---
#
# #### **Purchases vs Balance**
# **Description:**
# The scatter plot shows the relationship between "Purchases" and "Balance."
#
# **Key Observations:**
# - There is a positive correlation between purchases and balance. As purchases increase, the balance tends to increase as well.
# - Most data points cluster at lower values of both purchases and balance, suggesting moderate spending and balance maintenance for most individuals.
# - A few outliers show high purchase amounts with equally high balances, indicating unusual spending patterns.
#
# **Conclusion:**
# Higher purchases are generally associated with higher balances, and most individuals tend to maintain more moderate spending habits.
#
# ---

# %% [markdown]
# - relationship between `PURCHASES_FREQUENCY` and `CASH_ADVANCE`

# %%
plt.figure(figsize=(14,7))

sns.scatterplot(data=df,
                x='PURCHASES_FREQUENCY',
                y='CASH_ADVANCE',
                hue='PURCHASES_FREQUENCY',
                palette='viridis',
                alpha=0.7,
                size='CASH_ADVANCE',
                sizes=(20, 200))

plt.title('Purchases Frequency vs Cash Advance')
plt.xlabel('Purchases Frequency')
plt.ylabel('Cash Advance')
plt.show()

# %% [markdown]
# ---
#
# #### **Purchases Frequency vs Cash Advance**
# **Description:**
# The scatter plot shows the relationship between purchases frequency and cash advance.
#
# **Key Observations:**
# - There is a positive correlation between purchases frequency and cash advance. Customers who make more purchases tend to take out larger cash advances.
# - Most customers have low purchases frequency and low cash advance.
# - A small group of customers have high purchases frequency and high cash advance.
#
# **Conclusion:**
# Customers with higher purchase frequencies are more likely to take larger cash advances, suggesting a link between purchasing behavior and cash withdrawal habits.
#
# ---

# %% [markdown]
# ---
#
# ## **Checking for Outliers**
#
# - We use `boxplot` to display outliers in the numerical columns. This plot shows the distribution and outliers for each column.

# %%
df.shape
# Out:
# (8950, 17)

# %%
df.plot(kind="box", subplots=True, layout=(5,4), figsize=(18, 20))
plt.suptitle("Box Plot for Numeric Columns")
plt.show()

# %% [markdown]
# **Result:**
# From the boxplot, we observe several columns containing extreme values (outliers). However, due to the small size of the dataset, we decided not to remove these outliers. Instead, we handled them by compensating using the first or third quartiles through imputation.

# %% [markdown]
# ---
#
# ### **Handling Outliers**
#
# - We handle the outliers using the IQR (Interquartile Range) method, where we identify values that fall outside of this range and adjust them to be within the acceptable limits.

# %%
for col in df.columns:
    Q1 = data[col].quantile(0.25)
    Q3 = data[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    data[col] = np.where(data[col] < lower_bound, lower_bound, data[col])
    data[col] = np.where(data[col] > upper_bound, upper_bound, data[col])

# %% [markdown]
# ---
#
# ## Data Preparation: **Removing Unnecessary Columns Before Clustering**
#
# **Justification**:
# Before performing clustering (e.g., **K-Means**), unnecessary columns that do not significantly improve the model or are redundant were removed. The following columns were deleted:
#
# - **BALANCE_FREQUENCY**: Redundant with **BALANCE**.
# - **PURCHASES_FREQUENCY**: Represents the same concept as **PURCHASES_INSTALLMENTS_FREQUENCY**.
# - **CASH_ADVANCE_FREQUENCY**: Redundant with **CASH_ADVANCE_TRX**.
# - **TENURE**: Not impactful without a specific goal related to the account's duration.
# - **PRC_FULL_PAYMENT**: Unnecessary unless focusing on full payments analysis.
#
# ### Notes:
# - Columns were removed to improve model accuracy and simplify the data.
# - The goal is to retain the most impactful columns for efficient clustering.
#
# ---

# %%
df = df.drop(columns = ["ONEOFF_PURCHASES",
                     "INSTALLMENTS_PURCHASES",
                     "PURCHASES_INSTALLMENTS_FREQUENCY",
                     "CASH_ADVANCE_FREQUENCY",
                     "CASH_ADVANCE_TRX"])

df.head()
# Out:
#        BALANCE  BALANCE_FREQUENCY  PURCHASES  CASH_ADVANCE  \
# 0    40.900749           0.818182      95.40      0.000000
# 1  3202.467416           0.909091       0.00   6442.945483
# 2  2495.148862           1.000000     773.17      0.000000
# 3  1666.670542           0.636364    1499.00    205.788017
# 4   817.714335           1.000000      16.00      0.000000
#
#    PURCHASES_FREQUENCY  ONEOFF_PURCHASES_FREQUENCY  PURCHASES_TRX  \
# 0             0.166667                    0.000000              2
# 1             0.000000                    0.000000              0
# 2             1.000000                    1.000000             12
# 3             0.083333                    0.083333              1
# 4             0.083333                    0.083333              1
#
#    CREDIT_LIMIT     PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT  TENURE
# 0        1000.0   201.802084        139.509787          0.000000      12
# ...

# %% [markdown]
# ---
#
# ## **Feature Scaling**
#
# - **Explanation**:
#   - The `StandardScaler` from `sklearn.preprocessing` is imported to standardize the features.
#   - The `scaler.fit_transform(copy_data)` method is applied to the `df`, which scales the numerical features to have a mean of $0$ and a standard deviation of $1$. This ensures that all features are on the same scale, which is important for many machine learning algorithms.

# %%
from sklearn.preprocessing import StandardScaler

scaled = StandardScaler()
scaled
# Out:
# StandardScaler()

# %%
scaled_data = scaled.fit_transform(df)

# %% [markdown]
# ---
#
# ## **Dimensionality Reduction with PCA**
#
# - **Explanation**:
#   - `PCA` (Principal Component Analysis) is imported from `sklearn.decomposition` to perform dimensionality reduction.
#   - `pca.fit(scaled_data)` is used to compute the principal components of the scaled data. It learns the underlying structure of the data and extracts the most important information in fewer dimensions, helping to reduce the complexity of the data while preserving as much information as possible.

# %%
from sklearn.decomposition import PCA

pca = PCA()
pca.fit(scaled_data)
# Out:
# PCA()

# %% [markdown]
# #### **→ Selecting the Number of Principal Components to Retain $95$% of the Variance**

# %%
import numpy as np
from sklearn.decomposition import PCA

explained_variance = pca.explained_variance_ratio_
cumulative_variance = np.cumsum(explained_variance)
n_components = np.argmax(cumulative_variance >= 0.95) + 1
print(f"Number of components to retain 95% of the variance: {n_components}")
# Out:
# Number of components to retain 95% of the variance: 10

# %% [markdown]
# #### **→ Reducing Dimensions Using PCA with the Selected Number of Components**

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=n_components)
pca_data = pca.fit_transform(scaled_data)

# %% [markdown]
# ---
#
#
# ## **Methods to Determine the Optimal Number of Clusters**

# %% [markdown]
# ### **1. Elbow Method**

# %%
from sklearn.cluster import KMeans

inertia_values = []

for i in range(2,11) :
  model = KMeans(n_clusters=i , random_state=42)
  model.fit(pca_data)
  inertia_values.append(model.inertia_)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 5))
plt.plot(range(2,11), inertia_values , marker='|')

plt.xlabel('Number of Clusters')
plt.ylabel('Inertia Values')
plt.title('Elbow Method ')

plt.show()

# %% [markdown]
# ###  **2. Silhouette Score Method**

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

silhouette_scores = []

for k in range(2, 11):
  model = KMeans(n_clusters=k, random_state=42, n_init=10)
  model.fit(scaled_data)
  score = silhouette_score(scaled_data, model.labels_)
  silhouette_scores.append(score)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 5))
plt.plot(range(2,11), silhouette_scores, marker='o', color='red')

plt.xlabel('Number of clusters')
plt.ylabel('Silhouette Score')
plt.title('Silhouette Score Method')

plt.show()

# %% [markdown]
# ---
#
# ### **We Will Choose 7 Clusters Instead of 3**
#
# #### **1. Initial Evaluation: Elbow Method and Silhouette Score**
# - **Elbow Method** and **Silhouette Score** both suggested that **3 clusters** would offer a reasonable balance between within-cluster cohesion and between-cluster separation. However, the results showed that the segmentation could benefit from more granularity, as **7 clusters** offered clearer distinctions in customer behavior.
#
# #### **2. The Core Goal of the Project**
# - The primary goal of this project is to **segment customers based on their credit card usage behaviors** to help the bank's marketing team target the right groups with tailored offers and promotions.
# - A **more detailed segmentation** was needed to better capture the diverse spending habits, payment patterns, and credit usage among customers.
#
# #### **3. Why 7 Clusters?**
# - Choosing **7 clusters** enables a more granular understanding of the different types of customers based on their **spending behaviors**, **payment patterns**, and **credit limits**.
# - This **nuanced segmentation** helps the bank optimize marketing strategies, offering more personalized promotions to different customer groups.
#
# #### **4. Conclusion**
# - While 3 clusters provided a basic segmentation, the project's objective of developing **personalized marketing strategies** led to the decision to use **7 clusters**. This approach allows for a more comprehensive and actionable classification of customers, helping the bank target its marketing efforts more effectively.

# %% [markdown]
# ---
#
# ## **Creating the Model**

# %% [markdown]
# - Creating a KMeans Model with the Selected Number of Clusters

# %%
from sklearn.cluster import KMeans

kmean = KMeans(n_clusters=7, random_state=42)
kmean
# Out:
# KMeans(n_clusters=7, random_state=42)

# %% [markdown]
# - Training the Model

# %%
kmean.fit(pca_data)
# Out:
# KMeans(n_clusters=7, random_state=42)

# %% [markdown]
# - Getting the Cluster Labels from the Clustering Process

# %%
labels = kmean.labels_

# %% [markdown]
# - Adding the Labels to the DataFrame

# %%
data['Cluster'] = labels

# %% [markdown]
# ---
#
# ## **Analyzing Cluster Characteristics and Interpreting the Results**

# %% [markdown]
# - Assigning Cluster Labels to the Numeric Data

# %%
df['Cluster'] = labels

# %% [markdown]
# - Calculating Cluster Means

# %%
cluster_summary = df.groupby('Cluster').mean().T
cluster_summary
# Out:
# Cluster                               0            1            2  \
# BALANCE                     1836.890516   993.172652  5210.227126
# BALANCE_FREQUENCY              0.982581     0.967153     0.980310
# PURCHASES                   3092.192276   873.961037   516.163580
# CASH_ADVANCE                 460.344204   335.370557  3255.096861
# PURCHASES_FREQUENCY            0.949340     0.775193     0.278082
# ONEOFF_PURCHASES_FREQUENCY     0.784796     0.187620     0.100434
# PURCHASES_TRX                 46.339705    16.424537     7.357073
# CREDIT_LIMIT                7102.215465  3153.703852  8294.638581
# PAYMENTS                    2935.307051  1058.338316  2388.137423
# MINIMUM_PAYMENTS             696.883544   679.029905  2968.036313
# PRC_FULL_PAYMENT               0.258711     0.054935     0.010794
# TENURE                        11.894005    11.616946    11.639024
#
# Cluster                               3            4             5  \
# ...

# %% [markdown]
# - Assigning Labels to Clusters Using Mapped Values

# %%
labels_dict = {0: "Moderate Spenders",
               1: "Low-Engagement Users",
               2: "Cash-Dependent Users",
               3: "Debt-Free Users",
               4: "Financially Cautious",
               5: "Big Spenders",
               6: "High-Risk Financials"}

data['Cluster'] = data['Cluster'].map(labels_dict)

# %%
data.head()
# Out:
#   CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0  C10001    40.900749           0.818182      95.40            0.0000
# 1  C10002  3202.467416           0.909091       0.00            0.0000
# 2  C10003  2495.148862           1.000000     773.17          773.1700
# 3  C10004  1666.670542           0.722223    1499.00         1443.5125
# 4  C10005   817.714335           1.000000      16.00           16.0000
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   2784.552848             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# ...

# %% [markdown]
# | **$Cluster$** | **$Suggested Name$**      | **$Description$**                                                           |
# |-------------|-------------------------|---------------------------------------------------------------------------|
# | **$Cluster$ $0$** | Moderate Spenders      | Moderate Spending, Low Cash Advance, Balanced Payments, Regular Purchases |
# | **$Cluster$ $1$** | Low-Engagement Users   | Low Spending, Low Payments, Limited Credit Usage, Minimal Engagement      |
# | **$Cluster$ $2$** | Cash-Dependent Users   | Low Spending, High Cash Advance, Financial Instability, Cash-Dependent   |
# | **$Cluster$ $3$** | Debt-Free Users        | Low Spending, Full Payments, Financial Discipline, Debt-Free             |
# | **$Cluster$ $4$** | Financially Cautious   | Low Spending, High Cash Advance, Cautious Spending, Emergent Financial Needs |
# | **$Cluster$ $5$** | Big Spenders           | High Spending, Full Payments, Financially Stable, Luxury or Premium Customers |
# | **$Cluster$ $6$** | High-Risk Financials   | High Cash Advance, High Payments, Financial Strain, Heavy Debt Management |

# %% [markdown]
# - Extracting Countries with Low Income and Health Crisis

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

centroids = kmean.cluster_centers_

plt.figure(figsize=(6, 4))
sns.scatterplot(x=pca_data[:, 0], y=pca_data[:, 1], hue=kmean.labels_, palette='Set1', s=100, marker='o', edgecolor='black')

plt.scatter(centroids[:, 0], centroids[:, 1], s=200, c='white', marker='o', label='Centroids' ,edgecolors='red')

plt.title('Scatter Plot with KMeans Clusters and Centroids (PCA Reduced Data)')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.legend()
plt.show()

# %% [markdown]
# ---
#
# ### **Project Documentation: Customer Segmentation for Targeted Marketing in the Banking Sector Using Machine Learning**
#
# #### **1. Determining the Optimal Number of Clusters:**
#
# Before proceeding with the **clustering** process using **K-Means**, it was crucial to determine the optimal number of clusters (K). To achieve this, we employed two primary methods:
#
# - **Elbow Method**: The **Within-Cluster Sum of Squares (WCSS)** was computed for different values of K, and a plot was generated. By examining the plot, we identified the "elbow" point, where the WCSS improvement starts to slow down. This point represents the optimal number of clusters.
#
# - **Silhouette Score Method**: This method measures how similar an object is to its own cluster compared to other clusters. We computed the **Silhouette Score** for various K values and selected the one that gave the highest score, indicating the best-defined clusters.
#
# Based on both methods, we concluded that **7 clusters** is the ideal number, as it strikes a balance between quality and distinction between the groups.
#
# ---
#
# #### **2. Clustering Customers into 7 Groups:**
#
# Using **K-Means** with 7 clusters, customers were grouped into the following categories:
#
# 1. **Moderate Spenders**
#    - Customers in this group have moderate spending habits, with a balance and credit limit that suggest a middle-ground approach to spending. They also show a regular pattern of purchases, with balanced payments and low reliance on cash advances.
#
# 2. **Low-Engagement Users**
#    - These customers demonstrate low activity in terms of purchases and payments, with limited use of credit. They may rarely use their credit cards or engage in minimal transactions.
#
# 3. **Cash-Dependent Users**
#    - These customers tend to make high cash advances while keeping their spending low. Their financial behavior shows a reliance on credit for cash withdrawals rather than regular purchases.
#
# 4. **Debt-Free Users**
#    - Customers in this group exhibit a tendency to pay off their balances fully, demonstrating financial discipline. They tend to keep their spending low and avoid accumulating debt.
#
# 5. **Financially Cautious**
#    - These customers show low spending and high cash advance activity. They are careful in their spending habits, likely due to financial instability or concerns about future needs.
#
# 6. **Big Spenders**
#    - Customers in this group exhibit high spending levels, with a significant amount of purchases and high credit limits. They are financially stable and are likely to make luxury or premium purchases.
#
# 7. **High-Risk Financials**
#    - These customers show high cash advance activity and large payments, often indicating financial strain. They might be experiencing heavy debt management issues or financial instability.
#
# ---
#
# ### **3. Clusters & Marketing Strategy**
#
#
#
# | **$Cluster$**                         | **$Marketing-Strategy-Recommendations$**                                                                                                                                            |
# |-------------------------------------|------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# | **$Moderate$ $Spenders$**               | **Target with low-risk offers, such as cash-back or low-interest products that align with their moderate spending habits.**
# |
# | **$Low-Engagement$ $Users$**            | **Encourage engagement with campaigns aimed at increasing card usage, such as limited-time no-interest offers or rewards for frequent use.**
# |
# | **$Cash-Dependent$ $Users$**            | **Offer products that help reduce reliance on cash advances, such as low-interest cash withdrawal offers or cash-back rewards on purchases.**
# |
# | **$Debt-Free$ $Users$**                 | **Present premium services and products, such as exclusive credit cards with reward programs or personalized financial management tools.**
# |
# | **$Financially$ $Cautious$ $Users$**      | **Target with low-risk products focused on enhancing financial security, such as credit protection services or savings programs.**
# |
# | **$Big$ $Spenders$**                    | **Focus on exclusive offers and luxury products, such as elite travel packages or premium benefits for high-spending customers.**
# |
# | **$High-Risk$ $Financial$ $Users$**       | **Provide tailored offers to help them manage debt, such as balance transfer programs or financial consulting services.**
# |
#
#
# ---
#
# 1. **Moderate Spenders**
#    Target with mid-range offers and promotions. Encourage more frequent purchases without overwhelming them with debt.
#
# 2. **Low-Engagement Users**
#    Target with re-engagement campaigns to increase activity, such as bonus points or exclusive offers to activate card usage.
#
# 3. **Cash-Dependent Users**
#    Target with offers that focus on cash benefits, such as cash-back promotions or easy access to credit for cash withdrawals. Reduce reliance on cash advances.
#
# 4. **Debt-Free Users**
#    Offer products designed for savers, such as reward programs or low-interest rate offers. Focus on their financial stability and discipline.
#
# 5. **Financially Cautious Users**
#    Target with products that promote financial security, such as credit protection plans or financial advice services. Focus on security and reducing risk.
#
# 6. **Big Spenders**
#    Target with premium offers, exclusive privileges, and luxury products. Focus on high-end service and quality.
#
# 7. **High-Risk Financial Users**
#    Target with products focused on debt management or financial recovery, such as balance transfer promotions or financial counseling services.
#
# ---
